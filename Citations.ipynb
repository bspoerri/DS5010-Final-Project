# %% [markdown]
# ## Citations:
#
#
# dataset - https://archive.ics.uci.edu/dataset/186/wine+quality
#
# Background on Vihno Verde Wines - https://www.vinhoverde.pt/pt/a-instituicao/onde-estamos/
#
# Background on physicochemical markers - https://waterhouse.ucdavis.edu/whats-in-wine
#
# Sci-Kit Learn User Guide and API - https://scikit-learn.org/stable/user_guide.html
#
# Random Forest Hyperparamter Tuning - https://www.geeksforgeeks.org/machine-learning/random-forest-hyperparameter-tuning-in-python/
#
# Python Data Science Handbook (chapter 5) - https://jakevdp.github.io/PythonDataScienceHandbook/
